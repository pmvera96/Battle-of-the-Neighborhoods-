# %% [markdown]
# # Introduction

# %% [markdown]
# Toronto is the capital city of the Canadian province of Ontario. With a recorded population of 2,731,571 in 2016
# It is the most populous city in Canada and the fourth most populous city in North America.
# The city of Toronto is an international centre of business, finance, arts, and culture, and is recognized as one of the most multicultural and cosmopolitan cities in the world.
# Because of the information provided above it is fair to say that Toronto isa great city to consider when deciding to open up a business.
#
# # Problem
# In particular as a data scientist you have been hired to find the best place in Toronto to open up a Greek resturaunt.
# Finding a perfect location is complex and requires a series of factors to consider such as demogrhics,income,and competing venues.
# Fortuntley we have learned how to use data science tools to allow us to solve this issue and help our client make the most profits in their businees venture.
#  We will use Machine Leanring clustering methods to find the optimal location for our problem.

# %% [markdown]
# # Data

# %% [markdown]
# We will extract the neighbourhoods and boroughs from wikipedia using the following link: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:
# We will then obtain the geograpical coordinates using the python geocoder package
# Using the Neighbourhood profile dataset provided by https://www.toronto.ca/city-government/data-research-maps/neighbourhoods-communities/neighbourhood-profiles/ wil allow us
# to use additional imformation such as household income and demographics by neighbourhood to give us a better assesment in choosing the right location to open our restaurant.
# The foursquare api will be used to provide information on the type of venues found in each neighborhood, allowing to see the competition we will face.
